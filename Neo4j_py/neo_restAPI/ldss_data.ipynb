# %%
from cx_Oracle import connect as cx_connect
from cx_Oracle import DatabaseError

# %%
ORC_CONN = cx_connect("ALGO_DB_USER", "read", "racadmpe", False)

# %%
ORC_CURSOR = ORC_CONN.cursor()
stmt = ''' select PRJ_FUNC,DEPARTMENT, RECFILENAME,COUNTRY,ROAD_TYPE,LIGHT_CONDITIONS,WEATHER
FROM adms_teststage.ADMS_RESTRUCTURED_ENV_LABELS
where ROWNUM<100'''
ORC_CURSOR.execute(stmt)
ORC_CURSOR.arraysize = 50
data = ORC_CURSOR.fetchall()
all_data = []
for item in data:
    colun_names = [column[0] for column in ORC_CURSOR.description]
    # print "colun_names",colun_names
    data = dict(zip(colun_names, item))
    all_data.append(data)

# %%
all_data
# Out:
# [{'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.04_at_14.37.07.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.29_at_23.04.22.rec',
#   'ROAD_TYPE': 'Highway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.29_at_19.45.00.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Hungary',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': '20150731_0439_{7B17D7CD-A8C7-4F64-B08B-4702C55F3D32}.rrec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Germany',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Snapshot_2015.07.23_at_12.56.57.rec',
#   'ROAD_TYPE': 'Highway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Germany',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Snapshot_2015.07.23_at_12.56.57.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Germany',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Snapshot_2015.07.24_at_10.09.34.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.29_at_14.17.43.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.29_at_19.28.23.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Germany',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Snapshot_2015.07.23_at_13.04.26.rec',
#   'ROAD_TYPE': 'Highway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.30_at_15.23.24.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.03_at_17.25.08.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.30_at_21.39.28.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.29_at_13.50.15.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.03_at_16.49.42.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.30_at_12.58.39.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Great_Britain',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.13_at_12.19.46.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Great_Britain',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.13_at_10.18.31.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Germany',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.14_at_21.29.45.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.04_at_22.01.27.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Rain'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_11.52.06.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_11.52.06.rec',
#   'ROAD_TYPE': 'Other',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_11.52.06.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_11.52.06.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_11.52.06.rec',
#   'ROAD_TYPE': 'Other',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_11.52.06.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_11.52.06.rec',
#   'ROAD_TYPE': 'Other',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_11.52.06.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Austria',
#   'DEPARTMENT': 'EVA',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Snapshot_2015.11.09_at_11.32.35.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.01_at_16.39.12.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Austria',
#   'DEPARTMENT': 'EVA',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Snapshot_2015.11.09_at_13.40.38.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Luxemburg',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.11_at_17.47.17.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Rain'},
#  {'COUNTRY': 'Belgium',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.11_at_19.29.46.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Great_Britain',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.12_at_22.25.49.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Great_Britain',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.12_at_22.25.49.rec',
#   'ROAD_TYPE': 'Highway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Great_Britain',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.12_at_22.25.49.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Rain'},
#  {'COUNTRY': 'Great_Britain',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.12_at_22.25.49.rec',
#   'ROAD_TYPE': 'Highway',
#   'WEATHER': 'Rain'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_18.13.23.rec',
#   'ROAD_TYPE': 'Highway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_09.38.03.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_15.57.24.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_15.57.24.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_15.57.24.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_14.49.01.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_16.03.03.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_17.51.03.rec',
#   'ROAD_TYPE': 'Highway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.01_at_17.19.25.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.01_at_17.19.25.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_18.10.48.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_18.26.35.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_17.35.32.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_17.24.42.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_17.24.42.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_17.24.42.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_18.21.13.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.29_at_15.14.40.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Dusk',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.01_at_18.01.15.rec',
#   'ROAD_TYPE': 'Highway',
#   'WEATHER': 'Rain'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.04_at_12.19.56.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Great_Britain',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.13_at_14.58.53.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Great_Britain',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.13_at_14.58.53.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Great_Britain',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.13_at_14.58.53.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Great_Britain',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.13_at_14.58.53.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Great_Britain',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.09.13_at_14.58.53.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.29_at_13.04.19.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'EVA',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.10_at_13.44.14.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'EVA',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.10_at_13.44.14.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'EVA',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.10_at_22.40.17.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'EVA',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.10_at_22.40.17.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_14.52.04.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Germany',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Snapshot_2015.07.24_at_08.42.42.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Germany',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Snapshot_2015.07.24_at_08.42.42.rec',
#   'ROAD_TYPE': 'Highway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'Italy',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': '20141215_1540_{08627FB2-FDC3-414E-92B3-EBE39884DA8F}.rrec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_14.25.37.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.09_at_20.47.57.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.10_at_15.30.37.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_16.22.12.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.27_at_16.22.12.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_12.47.43.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.10_at_09.43.17.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.11_at_10.33.04.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.16_at_12.10.00.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.16_at_12.10.00.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.16_at_14.02.06.rec',
#   'ROAD_TYPE': 'Highway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.10_at_19.53.47.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.10_at_19.53.47.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.01_at_17.53.11.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.04_at_22.13.36.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Rain'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.02.09_at_09.43.21.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'TAIWAN',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2014.11.25_at_17.45.07.rec',
#   'ROAD_TYPE': 'Highway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.04_at_14.29.10.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.29_at_19.09.44.rec',
#   'ROAD_TYPE': 'Motorway',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.29_at_17.05.58.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.06.29_at_19.40.59.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Dusk',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.04_at_19.14.47.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Dusk',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.04_at_19.30.58.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.04_at_19.28.05.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'USA',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Day',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2011.07.04_at_19.32.57.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'France',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.04.18_at_20.53.17.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'France',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.04.18_at_20.53.17.rec',
#   'ROAD_TYPE': 'Country_Road',
#   'WEATHER': 'Dry'},
#  {'COUNTRY': 'France',
#   'DEPARTMENT': 'DEV',
#   'LIGHT_CONDITIONS': 'Night',
#   'PRJ_FUNC': 'MFC400_SR  ',
#   'RECFILENAME': 'Continuous_2012.04.18_at_20.53.17.rec',
#   'ROAD_TYPE': 'City',
#   'WEATHER': 'Dry'}]

# %%
import pandas as pd
ldss_dtfr = pd.DataFrame(all_data)
# ldss_dtfr.to_csv("ldss.csv", encoding='utf-8', index=False)

# %%
ldss_dtfr
# Out:
#           COUNTRY DEPARTMENT LIGHT_CONDITIONS     PRJ_FUNC  \
# 0             USA        DEV              Day  MFC400_SR
# 1             USA        DEV            Night  MFC400_SR
# 2             USA        DEV              Day  MFC400_SR
# 3         Hungary        DEV              Day  MFC400_SR
# 4         Germany        DEV              Day  MFC400_SR
# 5         Germany        DEV              Day  MFC400_SR
# 6         Germany        DEV              Day  MFC400_SR
# 7             USA        DEV              Day  MFC400_SR
# 8             USA        DEV              Day  MFC400_SR
# 9         Germany        DEV              Day  MFC400_SR
# 10            USA        DEV              Day  MFC400_SR
# 11            USA        DEV              Day  MFC400_SR
# 12            USA        DEV            Night  MFC400_SR
# 13            USA        DEV              Day  MFC400_SR
# 14            USA        DEV              Day  MFC400_SR
# 15            USA        DEV              Day  MFC400_SR
# 16  Great_Britain        DEV              Day  MFC400_SR
# 17  Great_Britain        DEV              Day  MFC400_SR
# 18        Germany        DEV            Night  MFC400_SR
# 19            USA        DEV            Night  MFC400_SR
# 20            USA        DEV              Day  MFC400_SR
# 21            USA        DEV              Day  MFC400_SR
# 22            USA        DEV              Day  MFC400_SR
# 23            USA        DEV              Day  MFC400_SR
# 24            USA        DEV              Day  MFC400_SR
# 25            USA        DEV              Day  MFC400_SR
# 26            USA        DEV              Day  MFC400_SR
# 27            USA        DEV              Day  MFC400_SR
# 28        Austria        EVA              Day  MFC400_SR
# 29            USA        DEV              Day  MFC400_SR
# ..            ...        ...              ...          ...
# 69        Germany        DEV              Day  MFC400_SR
# 70          Italy        DEV            Night  MFC400_SR
# 71            USA        DEV              Day  MFC400_SR
# 72            USA        DEV            Night  MFC400_SR
# 73            USA        DEV              Day  MFC400_SR
# 74            USA        DEV              Day  MFC400_SR
# 75            USA        DEV              Day  MFC400_SR
# 76            USA        DEV              Day  MFC400_SR
# 77            USA        DEV              Day  MFC400_SR
# 78            USA        DEV              Day  MFC400_SR
# 79            USA        DEV              Day  MFC400_SR
# 80            USA        DEV              Day  MFC400_SR
# 81            USA        DEV              Day  MFC400_SR
# 82            USA        DEV            Night  MFC400_SR
# 83            USA        DEV            Night  MFC400_SR
# 84            USA        DEV              Day  MFC400_SR
# 85            USA        DEV            Night  MFC400_SR
# 86            USA        DEV              Day  MFC400_SR
# 87         TAIWAN        DEV            Night  MFC400_SR
# 88            USA        DEV              Day  MFC400_SR
# 89            USA        DEV              Day  MFC400_SR
# 90            USA        DEV              Day  MFC400_SR
# 91            USA        DEV              Day  MFC400_SR
# 92            USA        DEV             Dusk  MFC400_SR
# 93            USA        DEV             Dusk  MFC400_SR
# 94            USA        DEV              Day  MFC400_SR
# 95            USA        DEV              Day  MFC400_SR
# 96         France        DEV            Night  MFC400_SR
# 97         France        DEV            Night  MFC400_SR
# 98         France        DEV            Night  MFC400_SR
#
#                                           RECFILENAME     ROAD_TYPE WEATHER
# 0               Continuous_2011.07.04_at_14.37.07.rec      Motorway     Dry
# 1               Continuous_2011.06.29_at_23.04.22.rec       Highway     Dry
# 2               Continuous_2011.06.29_at_19.45.00.rec  Country_Road     Dry
# 3   20150731_0439_{7B17D7CD-A8C7-4F64-B08B-4702C55...      Motorway     Dry
# 4                 Snapshot_2015.07.23_at_12.56.57.rec       Highway     Dry
# 5                 Snapshot_2015.07.23_at_12.56.57.rec          City     Dry
# 6                 Snapshot_2015.07.24_at_10.09.34.rec      Motorway     Dry
# 7               Continuous_2011.06.29_at_14.17.43.rec  Country_Road     Dry
# 8               Continuous_2011.06.29_at_19.28.23.rec      Motorway     Dry
# 9                 Snapshot_2015.07.23_at_13.04.26.rec       Highway     Dry
# 10              Continuous_2011.06.30_at_15.23.24.rec      Motorway     Dry
# 11              Continuous_2011.07.03_at_17.25.08.rec      Motorway     Dry
# 12              Continuous_2011.06.30_at_21.39.28.rec      Motorway     Dry
# 13              Continuous_2011.06.29_at_13.50.15.rec          City     Dry
# 14              Continuous_2011.07.03_at_16.49.42.rec      Motorway     Dry
# 15              Continuous_2011.06.30_at_12.58.39.rec      Motorway     Dry
# 16              Continuous_2012.09.13_at_12.19.46.rec          City     Dry
# 17              Continuous_2012.09.13_at_10.18.31.rec      Motorway     Dry
# 18              Continuous_2012.09.14_at_21.29.45.rec      Motorway     Dry
# 19              Continuous_2011.07.04_at_22.01.27.rec      Motorway    Rain
# 20              Continuous_2011.02.11_at_11.52.06.rec          City     Dry
# 21              Continuous_2011.02.11_at_11.52.06.rec         Other     Dry
# 22              Continuous_2011.02.11_at_11.52.06.rec      Motorway     Dry
# 23              Continuous_2011.02.11_at_11.52.06.rec      Motorway     Dry
# 24              Continuous_2011.02.11_at_11.52.06.rec         Other     Dry
# 25              Continuous_2011.02.11_at_11.52.06.rec          City     Dry
# 26              Continuous_2011.02.11_at_11.52.06.rec         Other     Dry
# 27              Continuous_2011.02.11_at_11.52.06.rec      Motorway     Dry
# 28                Snapshot_2015.11.09_at_11.32.35.rec          City     Dry
# 29              Continuous_2011.07.01_at_16.39.12.rec      Motorway     Dry
# ..                                                ...           ...     ...
# 69                Snapshot_2015.07.24_at_08.42.42.rec       Highway     Dry
# 70  20141215_1540_{08627FB2-FDC3-414E-92B3-EBE3988...      Motorway     Dry
# 71              Continuous_2011.02.11_at_14.25.37.rec      Motorway     Dry
# 72              Continuous_2011.02.09_at_20.47.57.rec      Motorway     Dry
# 73              Continuous_2011.02.10_at_15.30.37.rec  Country_Road     Dry
# 74              Continuous_2011.06.27_at_16.22.12.rec          City     Dry
# 75              Continuous_2011.06.27_at_16.22.12.rec      Motorway     Dry
# 76              Continuous_2011.02.11_at_12.47.43.rec      Motorway     Dry
# 77              Continuous_2011.02.10_at_09.43.17.rec      Motorway     Dry
# 78              Continuous_2011.02.11_at_10.33.04.rec      Motorway     Dry
# 79              Continuous_2011.06.16_at_12.10.00.rec          City     Dry
# 80              Continuous_2011.06.16_at_12.10.00.rec      Motorway     Dry
# 81              Continuous_2011.06.16_at_14.02.06.rec       Highway     Dry
# 82              Continuous_2011.02.10_at_19.53.47.rec          City     Dry
# 83              Continuous_2011.02.10_at_19.53.47.rec  Country_Road     Dry
# 84              Continuous_2011.07.01_at_17.53.11.rec      Motorway     Dry
# 85              Continuous_2011.07.04_at_22.13.36.rec  Country_Road    Rain
# 86              Continuous_2011.02.09_at_09.43.21.rec      Motorway     Dry
# 87              Continuous_2014.11.25_at_17.45.07.rec       Highway     Dry
# 88              Continuous_2011.07.04_at_14.29.10.rec      Motorway     Dry
# 89              Continuous_2011.06.29_at_19.09.44.rec      Motorway     Dry
# 90              Continuous_2011.06.29_at_17.05.58.rec          City     Dry
# 91              Continuous_2011.06.29_at_19.40.59.rec  Country_Road     Dry
# 92              Continuous_2011.07.04_at_19.14.47.rec  Country_Road     Dry
# 93              Continuous_2011.07.04_at_19.30.58.rec  Country_Road     Dry
# 94              Continuous_2011.07.04_at_19.28.05.rec  Country_Road     Dry
# 95              Continuous_2011.07.04_at_19.32.57.rec  Country_Road     Dry
# 96              Continuous_2012.04.18_at_20.53.17.rec  Country_Road     Dry
# 97              Continuous_2012.04.18_at_20.53.17.rec  Country_Road     Dry
# 98              Continuous_2012.04.18_at_20.53.17.rec          City     Dry
#
# [99 rows x 7 columns]

# %%
# Add a new project and function column
def get_element(my_list, position):
    return my_list[position]
ldss_dtfr['PROJECT'] = ldss_dtfr.PRJ_FUNC.str.split('_').apply(get_element, position=0)
ldss_dtfr['FUNCTION'] = ldss_dtfr.PRJ_FUNC.str.split('_').apply(get_element, position=1)
ldss_dtfr
# Out:
#           COUNTRY DEPARTMENT LIGHT_CONDITIONS     PRJ_FUNC  \
# 0             USA        DEV              Day  MFC400_SR
# 1             USA        DEV            Night  MFC400_SR
# 2             USA        DEV              Day  MFC400_SR
# 3         Hungary        DEV              Day  MFC400_SR
# 4         Germany        DEV              Day  MFC400_SR
# 5         Germany        DEV              Day  MFC400_SR
# 6         Germany        DEV              Day  MFC400_SR
# 7             USA        DEV              Day  MFC400_SR
# 8             USA        DEV              Day  MFC400_SR
# 9         Germany        DEV              Day  MFC400_SR
# 10            USA        DEV              Day  MFC400_SR
# 11            USA        DEV              Day  MFC400_SR
# 12            USA        DEV            Night  MFC400_SR
# 13            USA        DEV              Day  MFC400_SR
# 14            USA        DEV              Day  MFC400_SR
# 15            USA        DEV              Day  MFC400_SR
# 16  Great_Britain        DEV              Day  MFC400_SR
# 17  Great_Britain        DEV              Day  MFC400_SR
# 18        Germany        DEV            Night  MFC400_SR
# 19            USA        DEV            Night  MFC400_SR
# 20            USA        DEV              Day  MFC400_SR
# 21            USA        DEV              Day  MFC400_SR
# 22            USA        DEV              Day  MFC400_SR
# 23            USA        DEV              Day  MFC400_SR
# 24            USA        DEV              Day  MFC400_SR
# 25            USA        DEV              Day  MFC400_SR
# 26            USA        DEV              Day  MFC400_SR
# 27            USA        DEV              Day  MFC400_SR
# 28        Austria        EVA              Day  MFC400_SR
# 29            USA        DEV              Day  MFC400_SR
# ..            ...        ...              ...          ...
# 69        Germany        DEV              Day  MFC400_SR
# 70          Italy        DEV            Night  MFC400_SR
# 71            USA        DEV              Day  MFC400_SR
# 72            USA        DEV            Night  MFC400_SR
# 73            USA        DEV              Day  MFC400_SR
# 74            USA        DEV              Day  MFC400_SR
# 75            USA        DEV              Day  MFC400_SR
# 76            USA        DEV              Day  MFC400_SR
# 77            USA        DEV              Day  MFC400_SR
# 78            USA        DEV              Day  MFC400_SR
# 79            USA        DEV              Day  MFC400_SR
# 80            USA        DEV              Day  MFC400_SR
# 81            USA        DEV              Day  MFC400_SR
# 82            USA        DEV            Night  MFC400_SR
# 83            USA        DEV            Night  MFC400_SR
# 84            USA        DEV              Day  MFC400_SR
# 85            USA        DEV            Night  MFC400_SR
# 86            USA        DEV              Day  MFC400_SR
# 87         TAIWAN        DEV            Night  MFC400_SR
# 88            USA        DEV              Day  MFC400_SR
# 89            USA        DEV              Day  MFC400_SR
# 90            USA        DEV              Day  MFC400_SR
# 91            USA        DEV              Day  MFC400_SR
# 92            USA        DEV             Dusk  MFC400_SR
# 93            USA        DEV             Dusk  MFC400_SR
# 94            USA        DEV              Day  MFC400_SR
# 95            USA        DEV              Day  MFC400_SR
# 96         France        DEV            Night  MFC400_SR
# 97         France        DEV            Night  MFC400_SR
# 98         France        DEV            Night  MFC400_SR
#
#                                           RECFILENAME     ROAD_TYPE WEATHER  \
# 0               Continuous_2011.07.04_at_14.37.07.rec      Motorway     Dry
# 1               Continuous_2011.06.29_at_23.04.22.rec       Highway     Dry
# 2               Continuous_2011.06.29_at_19.45.00.rec  Country_Road     Dry
# 3   20150731_0439_{7B17D7CD-A8C7-4F64-B08B-4702C55...      Motorway     Dry
# 4                 Snapshot_2015.07.23_at_12.56.57.rec       Highway     Dry
# 5                 Snapshot_2015.07.23_at_12.56.57.rec          City     Dry
# 6                 Snapshot_2015.07.24_at_10.09.34.rec      Motorway     Dry
# 7               Continuous_2011.06.29_at_14.17.43.rec  Country_Road     Dry
# 8               Continuous_2011.06.29_at_19.28.23.rec      Motorway     Dry
# 9                 Snapshot_2015.07.23_at_13.04.26.rec       Highway     Dry
# 10              Continuous_2011.06.30_at_15.23.24.rec      Motorway     Dry
# 11              Continuous_2011.07.03_at_17.25.08.rec      Motorway     Dry
# 12              Continuous_2011.06.30_at_21.39.28.rec      Motorway     Dry
# 13              Continuous_2011.06.29_at_13.50.15.rec          City     Dry
# 14              Continuous_2011.07.03_at_16.49.42.rec      Motorway     Dry
# 15              Continuous_2011.06.30_at_12.58.39.rec      Motorway     Dry
# 16              Continuous_2012.09.13_at_12.19.46.rec          City     Dry
# 17              Continuous_2012.09.13_at_10.18.31.rec      Motorway     Dry
# 18              Continuous_2012.09.14_at_21.29.45.rec      Motorway     Dry
# 19              Continuous_2011.07.04_at_22.01.27.rec      Motorway    Rain
# 20              Continuous_2011.02.11_at_11.52.06.rec          City     Dry
# 21              Continuous_2011.02.11_at_11.52.06.rec         Other     Dry
# 22              Continuous_2011.02.11_at_11.52.06.rec      Motorway     Dry
# 23              Continuous_2011.02.11_at_11.52.06.rec      Motorway     Dry
# 24              Continuous_2011.02.11_at_11.52.06.rec         Other     Dry
# 25              Continuous_2011.02.11_at_11.52.06.rec          City     Dry
# 26              Continuous_2011.02.11_at_11.52.06.rec         Other     Dry
# 27              Continuous_2011.02.11_at_11.52.06.rec      Motorway     Dry
# 28                Snapshot_2015.11.09_at_11.32.35.rec          City     Dry
# 29              Continuous_2011.07.01_at_16.39.12.rec      Motorway     Dry
# ..                                                ...           ...     ...
# 69                Snapshot_2015.07.24_at_08.42.42.rec       Highway     Dry
# 70  20141215_1540_{08627FB2-FDC3-414E-92B3-EBE3988...      Motorway     Dry
# 71              Continuous_2011.02.11_at_14.25.37.rec      Motorway     Dry
# 72              Continuous_2011.02.09_at_20.47.57.rec      Motorway     Dry
# 73              Continuous_2011.02.10_at_15.30.37.rec  Country_Road     Dry
# 74              Continuous_2011.06.27_at_16.22.12.rec          City     Dry
# 75              Continuous_2011.06.27_at_16.22.12.rec      Motorway     Dry
# 76              Continuous_2011.02.11_at_12.47.43.rec      Motorway     Dry
# 77              Continuous_2011.02.10_at_09.43.17.rec      Motorway     Dry
# 78              Continuous_2011.02.11_at_10.33.04.rec      Motorway     Dry
# 79              Continuous_2011.06.16_at_12.10.00.rec          City     Dry
# 80              Continuous_2011.06.16_at_12.10.00.rec      Motorway     Dry
# 81              Continuous_2011.06.16_at_14.02.06.rec       Highway     Dry
# 82              Continuous_2011.02.10_at_19.53.47.rec          City     Dry
# 83              Continuous_2011.02.10_at_19.53.47.rec  Country_Road     Dry
# 84              Continuous_2011.07.01_at_17.53.11.rec      Motorway     Dry
# 85              Continuous_2011.07.04_at_22.13.36.rec  Country_Road    Rain
# 86              Continuous_2011.02.09_at_09.43.21.rec      Motorway     Dry
# 87              Continuous_2014.11.25_at_17.45.07.rec       Highway     Dry
# 88              Continuous_2011.07.04_at_14.29.10.rec      Motorway     Dry
# 89              Continuous_2011.06.29_at_19.09.44.rec      Motorway     Dry
# 90              Continuous_2011.06.29_at_17.05.58.rec          City     Dry
# 91              Continuous_2011.06.29_at_19.40.59.rec  Country_Road     Dry
# 92              Continuous_2011.07.04_at_19.14.47.rec  Country_Road     Dry
# 93              Continuous_2011.07.04_at_19.30.58.rec  Country_Road     Dry
# 94              Continuous_2011.07.04_at_19.28.05.rec  Country_Road     Dry
# 95              Continuous_2011.07.04_at_19.32.57.rec  Country_Road     Dry
# 96              Continuous_2012.04.18_at_20.53.17.rec  Country_Road     Dry
# 97              Continuous_2012.04.18_at_20.53.17.rec  Country_Road     Dry
# 98              Continuous_2012.04.18_at_20.53.17.rec          City     Dry
#
#    PROJECT FUNCTION
# 0   MFC400     SR
# 1   MFC400     SR
# 2   MFC400     SR
# 3   MFC400     SR
# 4   MFC400     SR
# 5   MFC400     SR
# 6   MFC400     SR
# 7   MFC400     SR
# 8   MFC400     SR
# 9   MFC400     SR
# 10  MFC400     SR
# 11  MFC400     SR
# 12  MFC400     SR
# 13  MFC400     SR
# 14  MFC400     SR
# 15  MFC400     SR
# 16  MFC400     SR
# 17  MFC400     SR
# 18  MFC400     SR
# 19  MFC400     SR
# 20  MFC400     SR
# 21  MFC400     SR
# 22  MFC400     SR
# 23  MFC400     SR
# 24  MFC400     SR
# 25  MFC400     SR
# 26  MFC400     SR
# 27  MFC400     SR
# 28  MFC400     SR
# 29  MFC400     SR
# ..     ...      ...
# 69  MFC400     SR
# 70  MFC400     SR
# 71  MFC400     SR
# 72  MFC400     SR
# 73  MFC400     SR
# 74  MFC400     SR
# 75  MFC400     SR
# 76  MFC400     SR
# 77  MFC400     SR
# 78  MFC400     SR
# 79  MFC400     SR
# 80  MFC400     SR
# 81  MFC400     SR
# 82  MFC400     SR
# 83  MFC400     SR
# 84  MFC400     SR
# 85  MFC400     SR
# 86  MFC400     SR
# 87  MFC400     SR
# 88  MFC400     SR
# 89  MFC400     SR
# 90  MFC400     SR
# 91  MFC400     SR
# 92  MFC400     SR
# 93  MFC400     SR
# 94  MFC400     SR
# 95  MFC400     SR
# 96  MFC400     SR
# 97  MFC400     SR
# 98  MFC400     SR
#
# [99 rows x 9 columns]

# %%
# Index the Dataframe by recording name
idx_rec_dtfr = ldss_dtfr.set_index(['RECFILENAME'])
idx_rec_dtfr
# Out:
#                                                           COUNTRY DEPARTMENT  \
# RECFILENAME
# Continuous_2011.07.04_at_14.37.07.rec                         USA        DEV
# Continuous_2011.06.29_at_23.04.22.rec                         USA        DEV
# Continuous_2011.06.29_at_19.45.00.rec                         USA        DEV
# 20150731_0439_{7B17D7CD-A8C7-4F64-B08B-4702C55F...        Hungary        DEV
# Snapshot_2015.07.23_at_12.56.57.rec                       Germany        DEV
# Snapshot_2015.07.23_at_12.56.57.rec                       Germany        DEV
# Snapshot_2015.07.24_at_10.09.34.rec                       Germany        DEV
# Continuous_2011.06.29_at_14.17.43.rec                         USA        DEV
# Continuous_2011.06.29_at_19.28.23.rec                         USA        DEV
# Snapshot_2015.07.23_at_13.04.26.rec                       Germany        DEV
# Continuous_2011.06.30_at_15.23.24.rec                         USA        DEV
# Continuous_2011.07.03_at_17.25.08.rec                         USA        DEV
# Continuous_2011.06.30_at_21.39.28.rec                         USA        DEV
# Continuous_2011.06.29_at_13.50.15.rec                         USA        DEV
# Continuous_2011.07.03_at_16.49.42.rec                         USA        DEV
# Continuous_2011.06.30_at_12.58.39.rec                         USA        DEV
# Continuous_2012.09.13_at_12.19.46.rec               Great_Britain        DEV
# Continuous_2012.09.13_at_10.18.31.rec               Great_Britain        DEV
# Continuous_2012.09.14_at_21.29.45.rec                     Germany        DEV
# Continuous_2011.07.04_at_22.01.27.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Snapshot_2015.11.09_at_11.32.35.rec                       Austria        EVA
# Continuous_2011.07.01_at_16.39.12.rec                         USA        DEV
# ...                                                           ...        ...
# Snapshot_2015.07.24_at_08.42.42.rec                       Germany        DEV
# 20141215_1540_{08627FB2-FDC3-414E-92B3-EBE39884...          Italy        DEV
# Continuous_2011.02.11_at_14.25.37.rec                         USA        DEV
# Continuous_2011.02.09_at_20.47.57.rec                         USA        DEV
# Continuous_2011.02.10_at_15.30.37.rec                         USA        DEV
# Continuous_2011.06.27_at_16.22.12.rec                         USA        DEV
# Continuous_2011.06.27_at_16.22.12.rec                         USA        DEV
# Continuous_2011.02.11_at_12.47.43.rec                         USA        DEV
# Continuous_2011.02.10_at_09.43.17.rec                         USA        DEV
# Continuous_2011.02.11_at_10.33.04.rec                         USA        DEV
# Continuous_2011.06.16_at_12.10.00.rec                         USA        DEV
# Continuous_2011.06.16_at_12.10.00.rec                         USA        DEV
# Continuous_2011.06.16_at_14.02.06.rec                         USA        DEV
# Continuous_2011.02.10_at_19.53.47.rec                         USA        DEV
# Continuous_2011.02.10_at_19.53.47.rec                         USA        DEV
# Continuous_2011.07.01_at_17.53.11.rec                         USA        DEV
# Continuous_2011.07.04_at_22.13.36.rec                         USA        DEV
# Continuous_2011.02.09_at_09.43.21.rec                         USA        DEV
# Continuous_2014.11.25_at_17.45.07.rec                      TAIWAN        DEV
# Continuous_2011.07.04_at_14.29.10.rec                         USA        DEV
# Continuous_2011.06.29_at_19.09.44.rec                         USA        DEV
# Continuous_2011.06.29_at_17.05.58.rec                         USA        DEV
# Continuous_2011.06.29_at_19.40.59.rec                         USA        DEV
# Continuous_2011.07.04_at_19.14.47.rec                         USA        DEV
# Continuous_2011.07.04_at_19.30.58.rec                         USA        DEV
# Continuous_2011.07.04_at_19.28.05.rec                         USA        DEV
# Continuous_2011.07.04_at_19.32.57.rec                         USA        DEV
# Continuous_2012.04.18_at_20.53.17.rec                      France        DEV
# Continuous_2012.04.18_at_20.53.17.rec                      France        DEV
# Continuous_2012.04.18_at_20.53.17.rec                      France        DEV
#
#                                                    LIGHT_CONDITIONS  \
# RECFILENAME
# Continuous_2011.07.04_at_14.37.07.rec                           Day
# Continuous_2011.06.29_at_23.04.22.rec                         Night
# Continuous_2011.06.29_at_19.45.00.rec                           Day
# 20150731_0439_{7B17D7CD-A8C7-4F64-B08B-4702C55F...              Day
# Snapshot_2015.07.23_at_12.56.57.rec                             Day
# Snapshot_2015.07.23_at_12.56.57.rec                             Day
# Snapshot_2015.07.24_at_10.09.34.rec                             Day
# Continuous_2011.06.29_at_14.17.43.rec                           Day
# Continuous_2011.06.29_at_19.28.23.rec                           Day
# Snapshot_2015.07.23_at_13.04.26.rec                             Day
# Continuous_2011.06.30_at_15.23.24.rec                           Day
# Continuous_2011.07.03_at_17.25.08.rec                           Day
# Continuous_2011.06.30_at_21.39.28.rec                         Night
# Continuous_2011.06.29_at_13.50.15.rec                           Day
# Continuous_2011.07.03_at_16.49.42.rec                           Day
# Continuous_2011.06.30_at_12.58.39.rec                           Day
# Continuous_2012.09.13_at_12.19.46.rec                           Day
# Continuous_2012.09.13_at_10.18.31.rec                           Day
# Continuous_2012.09.14_at_21.29.45.rec                         Night
# Continuous_2011.07.04_at_22.01.27.rec                         Night
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Snapshot_2015.11.09_at_11.32.35.rec                             Day
# Continuous_2011.07.01_at_16.39.12.rec                           Day
# ...                                                             ...
# Snapshot_2015.07.24_at_08.42.42.rec                             Day
# 20141215_1540_{08627FB2-FDC3-414E-92B3-EBE39884...            Night
# Continuous_2011.02.11_at_14.25.37.rec                           Day
# Continuous_2011.02.09_at_20.47.57.rec                         Night
# Continuous_2011.02.10_at_15.30.37.rec                           Day
# Continuous_2011.06.27_at_16.22.12.rec                           Day
# Continuous_2011.06.27_at_16.22.12.rec                           Day
# Continuous_2011.02.11_at_12.47.43.rec                           Day
# Continuous_2011.02.10_at_09.43.17.rec                           Day
# Continuous_2011.02.11_at_10.33.04.rec                           Day
# Continuous_2011.06.16_at_12.10.00.rec                           Day
# Continuous_2011.06.16_at_12.10.00.rec                           Day
# Continuous_2011.06.16_at_14.02.06.rec                           Day
# Continuous_2011.02.10_at_19.53.47.rec                         Night
# Continuous_2011.02.10_at_19.53.47.rec                         Night
# Continuous_2011.07.01_at_17.53.11.rec                           Day
# Continuous_2011.07.04_at_22.13.36.rec                         Night
# Continuous_2011.02.09_at_09.43.21.rec                           Day
# Continuous_2014.11.25_at_17.45.07.rec                         Night
# Continuous_2011.07.04_at_14.29.10.rec                           Day
# Continuous_2011.06.29_at_19.09.44.rec                           Day
# Continuous_2011.06.29_at_17.05.58.rec                           Day
# Continuous_2011.06.29_at_19.40.59.rec                           Day
# Continuous_2011.07.04_at_19.14.47.rec                          Dusk
# Continuous_2011.07.04_at_19.30.58.rec                          Dusk
# Continuous_2011.07.04_at_19.28.05.rec                           Day
# Continuous_2011.07.04_at_19.32.57.rec                           Day
# Continuous_2012.04.18_at_20.53.17.rec                         Night
# Continuous_2012.04.18_at_20.53.17.rec                         Night
# Continuous_2012.04.18_at_20.53.17.rec                         Night
#
#                                                        PRJ_FUNC     ROAD_TYPE  \
# RECFILENAME
# Continuous_2011.07.04_at_14.37.07.rec               MFC400_SR        Motorway
# Continuous_2011.06.29_at_23.04.22.rec               MFC400_SR         Highway
# Continuous_2011.06.29_at_19.45.00.rec               MFC400_SR    Country_Road
# 20150731_0439_{7B17D7CD-A8C7-4F64-B08B-4702C55F...  MFC400_SR        Motorway
# Snapshot_2015.07.23_at_12.56.57.rec                 MFC400_SR         Highway
# Snapshot_2015.07.23_at_12.56.57.rec                 MFC400_SR            City
# Snapshot_2015.07.24_at_10.09.34.rec                 MFC400_SR        Motorway
# Continuous_2011.06.29_at_14.17.43.rec               MFC400_SR    Country_Road
# Continuous_2011.06.29_at_19.28.23.rec               MFC400_SR        Motorway
# Snapshot_2015.07.23_at_13.04.26.rec                 MFC400_SR         Highway
# Continuous_2011.06.30_at_15.23.24.rec               MFC400_SR        Motorway
# Continuous_2011.07.03_at_17.25.08.rec               MFC400_SR        Motorway
# Continuous_2011.06.30_at_21.39.28.rec               MFC400_SR        Motorway
# Continuous_2011.06.29_at_13.50.15.rec               MFC400_SR            City
# Continuous_2011.07.03_at_16.49.42.rec               MFC400_SR        Motorway
# Continuous_2011.06.30_at_12.58.39.rec               MFC400_SR        Motorway
# Continuous_2012.09.13_at_12.19.46.rec               MFC400_SR            City
# Continuous_2012.09.13_at_10.18.31.rec               MFC400_SR        Motorway
# Continuous_2012.09.14_at_21.29.45.rec               MFC400_SR        Motorway
# Continuous_2011.07.04_at_22.01.27.rec               MFC400_SR        Motorway
# Continuous_2011.02.11_at_11.52.06.rec               MFC400_SR            City
# Continuous_2011.02.11_at_11.52.06.rec               MFC400_SR           Other
# Continuous_2011.02.11_at_11.52.06.rec               MFC400_SR        Motorway
# Continuous_2011.02.11_at_11.52.06.rec               MFC400_SR        Motorway
# Continuous_2011.02.11_at_11.52.06.rec               MFC400_SR           Other
# Continuous_2011.02.11_at_11.52.06.rec               MFC400_SR            City
# Continuous_2011.02.11_at_11.52.06.rec               MFC400_SR           Other
# Continuous_2011.02.11_at_11.52.06.rec               MFC400_SR        Motorway
# Snapshot_2015.11.09_at_11.32.35.rec                 MFC400_SR            City
# Continuous_2011.07.01_at_16.39.12.rec               MFC400_SR        Motorway
# ...                                                         ...           ...
# Snapshot_2015.07.24_at_08.42.42.rec                 MFC400_SR         Highway
# 20141215_1540_{08627FB2-FDC3-414E-92B3-EBE39884...  MFC400_SR        Motorway
# Continuous_2011.02.11_at_14.25.37.rec               MFC400_SR        Motorway
# Continuous_2011.02.09_at_20.47.57.rec               MFC400_SR        Motorway
# Continuous_2011.02.10_at_15.30.37.rec               MFC400_SR    Country_Road
# Continuous_2011.06.27_at_16.22.12.rec               MFC400_SR            City
# Continuous_2011.06.27_at_16.22.12.rec               MFC400_SR        Motorway
# Continuous_2011.02.11_at_12.47.43.rec               MFC400_SR        Motorway
# Continuous_2011.02.10_at_09.43.17.rec               MFC400_SR        Motorway
# Continuous_2011.02.11_at_10.33.04.rec               MFC400_SR        Motorway
# Continuous_2011.06.16_at_12.10.00.rec               MFC400_SR            City
# Continuous_2011.06.16_at_12.10.00.rec               MFC400_SR        Motorway
# Continuous_2011.06.16_at_14.02.06.rec               MFC400_SR         Highway
# Continuous_2011.02.10_at_19.53.47.rec               MFC400_SR            City
# Continuous_2011.02.10_at_19.53.47.rec               MFC400_SR    Country_Road
# Continuous_2011.07.01_at_17.53.11.rec               MFC400_SR        Motorway
# Continuous_2011.07.04_at_22.13.36.rec               MFC400_SR    Country_Road
# Continuous_2011.02.09_at_09.43.21.rec               MFC400_SR        Motorway
# Continuous_2014.11.25_at_17.45.07.rec               MFC400_SR         Highway
# Continuous_2011.07.04_at_14.29.10.rec               MFC400_SR        Motorway
# Continuous_2011.06.29_at_19.09.44.rec               MFC400_SR        Motorway
# Continuous_2011.06.29_at_17.05.58.rec               MFC400_SR            City
# Continuous_2011.06.29_at_19.40.59.rec               MFC400_SR    Country_Road
# Continuous_2011.07.04_at_19.14.47.rec               MFC400_SR    Country_Road
# Continuous_2011.07.04_at_19.30.58.rec               MFC400_SR    Country_Road
# Continuous_2011.07.04_at_19.28.05.rec               MFC400_SR    Country_Road
# Continuous_2011.07.04_at_19.32.57.rec               MFC400_SR    Country_Road
# Continuous_2012.04.18_at_20.53.17.rec               MFC400_SR    Country_Road
# Continuous_2012.04.18_at_20.53.17.rec               MFC400_SR    Country_Road
# Continuous_2012.04.18_at_20.53.17.rec               MFC400_SR            City
#
#                                                    WEATHER PROJECT FUNCTION
# RECFILENAME
# Continuous_2011.07.04_at_14.37.07.rec                  Dry  MFC400     SR
# Continuous_2011.06.29_at_23.04.22.rec                  Dry  MFC400     SR
# Continuous_2011.06.29_at_19.45.00.rec                  Dry  MFC400     SR
# 20150731_0439_{7B17D7CD-A8C7-4F64-B08B-4702C55F...     Dry  MFC400     SR
# Snapshot_2015.07.23_at_12.56.57.rec                    Dry  MFC400     SR
# Snapshot_2015.07.23_at_12.56.57.rec                    Dry  MFC400     SR
# Snapshot_2015.07.24_at_10.09.34.rec                    Dry  MFC400     SR
# Continuous_2011.06.29_at_14.17.43.rec                  Dry  MFC400     SR
# Continuous_2011.06.29_at_19.28.23.rec                  Dry  MFC400     SR
# Snapshot_2015.07.23_at_13.04.26.rec                    Dry  MFC400     SR
# Continuous_2011.06.30_at_15.23.24.rec                  Dry  MFC400     SR
# Continuous_2011.07.03_at_17.25.08.rec                  Dry  MFC400     SR
# Continuous_2011.06.30_at_21.39.28.rec                  Dry  MFC400     SR
# Continuous_2011.06.29_at_13.50.15.rec                  Dry  MFC400     SR
# Continuous_2011.07.03_at_16.49.42.rec                  Dry  MFC400     SR
# Continuous_2011.06.30_at_12.58.39.rec                  Dry  MFC400     SR
# Continuous_2012.09.13_at_12.19.46.rec                  Dry  MFC400     SR
# Continuous_2012.09.13_at_10.18.31.rec                  Dry  MFC400     SR
# Continuous_2012.09.14_at_21.29.45.rec                  Dry  MFC400     SR
# Continuous_2011.07.04_at_22.01.27.rec                 Rain  MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec                  Dry  MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec                  Dry  MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec                  Dry  MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec                  Dry  MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec                  Dry  MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec                  Dry  MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec                  Dry  MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec                  Dry  MFC400     SR
# Snapshot_2015.11.09_at_11.32.35.rec                    Dry  MFC400     SR
# Continuous_2011.07.01_at_16.39.12.rec                  Dry  MFC400     SR
# ...                                                    ...     ...      ...
# Snapshot_2015.07.24_at_08.42.42.rec                    Dry  MFC400     SR
# 20141215_1540_{08627FB2-FDC3-414E-92B3-EBE39884...     Dry  MFC400     SR
# Continuous_2011.02.11_at_14.25.37.rec                  Dry  MFC400     SR
# Continuous_2011.02.09_at_20.47.57.rec                  Dry  MFC400     SR
# Continuous_2011.02.10_at_15.30.37.rec                  Dry  MFC400     SR
# Continuous_2011.06.27_at_16.22.12.rec                  Dry  MFC400     SR
# Continuous_2011.06.27_at_16.22.12.rec                  Dry  MFC400     SR
# Continuous_2011.02.11_at_12.47.43.rec                  Dry  MFC400     SR
# Continuous_2011.02.10_at_09.43.17.rec                  Dry  MFC400     SR
# Continuous_2011.02.11_at_10.33.04.rec                  Dry  MFC400     SR
# Continuous_2011.06.16_at_12.10.00.rec                  Dry  MFC400     SR
# Continuous_2011.06.16_at_12.10.00.rec                  Dry  MFC400     SR
# Continuous_2011.06.16_at_14.02.06.rec                  Dry  MFC400     SR
# Continuous_2011.02.10_at_19.53.47.rec                  Dry  MFC400     SR
# Continuous_2011.02.10_at_19.53.47.rec                  Dry  MFC400     SR
# Continuous_2011.07.01_at_17.53.11.rec                  Dry  MFC400     SR
# Continuous_2011.07.04_at_22.13.36.rec                 Rain  MFC400     SR
# Continuous_2011.02.09_at_09.43.21.rec                  Dry  MFC400     SR
# Continuous_2014.11.25_at_17.45.07.rec                  Dry  MFC400     SR
# Continuous_2011.07.04_at_14.29.10.rec                  Dry  MFC400     SR
# Continuous_2011.06.29_at_19.09.44.rec                  Dry  MFC400     SR
# Continuous_2011.06.29_at_17.05.58.rec                  Dry  MFC400     SR
# Continuous_2011.06.29_at_19.40.59.rec                  Dry  MFC400     SR
# Continuous_2011.07.04_at_19.14.47.rec                  Dry  MFC400     SR
# Continuous_2011.07.04_at_19.30.58.rec                  Dry  MFC400     SR
# Continuous_2011.07.04_at_19.28.05.rec                  Dry  MFC400     SR
# Continuous_2011.07.04_at_19.32.57.rec                  Dry  MFC400     SR
# Continuous_2012.04.18_at_20.53.17.rec                  Dry  MFC400     SR
# Continuous_2012.04.18_at_20.53.17.rec                  Dry  MFC400     SR
# Continuous_2012.04.18_at_20.53.17.rec                  Dry  MFC400     SR
#
# [99 rows x 8 columns]

# %%
# Delete the PRJ_FUNC column
del idx_rec_dtfr['PRJ_FUNC']
idx_rec_dtfr
# Out:
#                                                           COUNTRY DEPARTMENT  \
# RECFILENAME
# Continuous_2011.07.04_at_14.37.07.rec                         USA        DEV
# Continuous_2011.06.29_at_23.04.22.rec                         USA        DEV
# Continuous_2011.06.29_at_19.45.00.rec                         USA        DEV
# 20150731_0439_{7B17D7CD-A8C7-4F64-B08B-4702C55F...        Hungary        DEV
# Snapshot_2015.07.23_at_12.56.57.rec                       Germany        DEV
# Snapshot_2015.07.23_at_12.56.57.rec                       Germany        DEV
# Snapshot_2015.07.24_at_10.09.34.rec                       Germany        DEV
# Continuous_2011.06.29_at_14.17.43.rec                         USA        DEV
# Continuous_2011.06.29_at_19.28.23.rec                         USA        DEV
# Snapshot_2015.07.23_at_13.04.26.rec                       Germany        DEV
# Continuous_2011.06.30_at_15.23.24.rec                         USA        DEV
# Continuous_2011.07.03_at_17.25.08.rec                         USA        DEV
# Continuous_2011.06.30_at_21.39.28.rec                         USA        DEV
# Continuous_2011.06.29_at_13.50.15.rec                         USA        DEV
# Continuous_2011.07.03_at_16.49.42.rec                         USA        DEV
# Continuous_2011.06.30_at_12.58.39.rec                         USA        DEV
# Continuous_2012.09.13_at_12.19.46.rec               Great_Britain        DEV
# Continuous_2012.09.13_at_10.18.31.rec               Great_Britain        DEV
# Continuous_2012.09.14_at_21.29.45.rec                     Germany        DEV
# Continuous_2011.07.04_at_22.01.27.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Continuous_2011.02.11_at_11.52.06.rec                         USA        DEV
# Snapshot_2015.11.09_at_11.32.35.rec                       Austria        EVA
# Continuous_2011.07.01_at_16.39.12.rec                         USA        DEV
# ...                                                           ...        ...
# Snapshot_2015.07.24_at_08.42.42.rec                       Germany        DEV
# 20141215_1540_{08627FB2-FDC3-414E-92B3-EBE39884...          Italy        DEV
# Continuous_2011.02.11_at_14.25.37.rec                         USA        DEV
# Continuous_2011.02.09_at_20.47.57.rec                         USA        DEV
# Continuous_2011.02.10_at_15.30.37.rec                         USA        DEV
# Continuous_2011.06.27_at_16.22.12.rec                         USA        DEV
# Continuous_2011.06.27_at_16.22.12.rec                         USA        DEV
# Continuous_2011.02.11_at_12.47.43.rec                         USA        DEV
# Continuous_2011.02.10_at_09.43.17.rec                         USA        DEV
# Continuous_2011.02.11_at_10.33.04.rec                         USA        DEV
# Continuous_2011.06.16_at_12.10.00.rec                         USA        DEV
# Continuous_2011.06.16_at_12.10.00.rec                         USA        DEV
# Continuous_2011.06.16_at_14.02.06.rec                         USA        DEV
# Continuous_2011.02.10_at_19.53.47.rec                         USA        DEV
# Continuous_2011.02.10_at_19.53.47.rec                         USA        DEV
# Continuous_2011.07.01_at_17.53.11.rec                         USA        DEV
# Continuous_2011.07.04_at_22.13.36.rec                         USA        DEV
# Continuous_2011.02.09_at_09.43.21.rec                         USA        DEV
# Continuous_2014.11.25_at_17.45.07.rec                      TAIWAN        DEV
# Continuous_2011.07.04_at_14.29.10.rec                         USA        DEV
# Continuous_2011.06.29_at_19.09.44.rec                         USA        DEV
# Continuous_2011.06.29_at_17.05.58.rec                         USA        DEV
# Continuous_2011.06.29_at_19.40.59.rec                         USA        DEV
# Continuous_2011.07.04_at_19.14.47.rec                         USA        DEV
# Continuous_2011.07.04_at_19.30.58.rec                         USA        DEV
# Continuous_2011.07.04_at_19.28.05.rec                         USA        DEV
# Continuous_2011.07.04_at_19.32.57.rec                         USA        DEV
# Continuous_2012.04.18_at_20.53.17.rec                      France        DEV
# Continuous_2012.04.18_at_20.53.17.rec                      France        DEV
# Continuous_2012.04.18_at_20.53.17.rec                      France        DEV
#
#                                                    LIGHT_CONDITIONS  \
# RECFILENAME
# Continuous_2011.07.04_at_14.37.07.rec                           Day
# Continuous_2011.06.29_at_23.04.22.rec                         Night
# Continuous_2011.06.29_at_19.45.00.rec                           Day
# 20150731_0439_{7B17D7CD-A8C7-4F64-B08B-4702C55F...              Day
# Snapshot_2015.07.23_at_12.56.57.rec                             Day
# Snapshot_2015.07.23_at_12.56.57.rec                             Day
# Snapshot_2015.07.24_at_10.09.34.rec                             Day
# Continuous_2011.06.29_at_14.17.43.rec                           Day
# Continuous_2011.06.29_at_19.28.23.rec                           Day
# Snapshot_2015.07.23_at_13.04.26.rec                             Day
# Continuous_2011.06.30_at_15.23.24.rec                           Day
# Continuous_2011.07.03_at_17.25.08.rec                           Day
# Continuous_2011.06.30_at_21.39.28.rec                         Night
# Continuous_2011.06.29_at_13.50.15.rec                           Day
# Continuous_2011.07.03_at_16.49.42.rec                           Day
# Continuous_2011.06.30_at_12.58.39.rec                           Day
# Continuous_2012.09.13_at_12.19.46.rec                           Day
# Continuous_2012.09.13_at_10.18.31.rec                           Day
# Continuous_2012.09.14_at_21.29.45.rec                         Night
# Continuous_2011.07.04_at_22.01.27.rec                         Night
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Continuous_2011.02.11_at_11.52.06.rec                           Day
# Snapshot_2015.11.09_at_11.32.35.rec                             Day
# Continuous_2011.07.01_at_16.39.12.rec                           Day
# ...                                                             ...
# Snapshot_2015.07.24_at_08.42.42.rec                             Day
# 20141215_1540_{08627FB2-FDC3-414E-92B3-EBE39884...            Night
# Continuous_2011.02.11_at_14.25.37.rec                           Day
# Continuous_2011.02.09_at_20.47.57.rec                         Night
# Continuous_2011.02.10_at_15.30.37.rec                           Day
# Continuous_2011.06.27_at_16.22.12.rec                           Day
# Continuous_2011.06.27_at_16.22.12.rec                           Day
# Continuous_2011.02.11_at_12.47.43.rec                           Day
# Continuous_2011.02.10_at_09.43.17.rec                           Day
# Continuous_2011.02.11_at_10.33.04.rec                           Day
# Continuous_2011.06.16_at_12.10.00.rec                           Day
# Continuous_2011.06.16_at_12.10.00.rec                           Day
# Continuous_2011.06.16_at_14.02.06.rec                           Day
# Continuous_2011.02.10_at_19.53.47.rec                         Night
# Continuous_2011.02.10_at_19.53.47.rec                         Night
# Continuous_2011.07.01_at_17.53.11.rec                           Day
# Continuous_2011.07.04_at_22.13.36.rec                         Night
# Continuous_2011.02.09_at_09.43.21.rec                           Day
# Continuous_2014.11.25_at_17.45.07.rec                         Night
# Continuous_2011.07.04_at_14.29.10.rec                           Day
# Continuous_2011.06.29_at_19.09.44.rec                           Day
# Continuous_2011.06.29_at_17.05.58.rec                           Day
# Continuous_2011.06.29_at_19.40.59.rec                           Day
# Continuous_2011.07.04_at_19.14.47.rec                          Dusk
# Continuous_2011.07.04_at_19.30.58.rec                          Dusk
# Continuous_2011.07.04_at_19.28.05.rec                           Day
# Continuous_2011.07.04_at_19.32.57.rec                           Day
# Continuous_2012.04.18_at_20.53.17.rec                         Night
# Continuous_2012.04.18_at_20.53.17.rec                         Night
# Continuous_2012.04.18_at_20.53.17.rec                         Night
#
#                                                        ROAD_TYPE WEATHER  \
# RECFILENAME
# Continuous_2011.07.04_at_14.37.07.rec                   Motorway     Dry
# Continuous_2011.06.29_at_23.04.22.rec                    Highway     Dry
# Continuous_2011.06.29_at_19.45.00.rec               Country_Road     Dry
# 20150731_0439_{7B17D7CD-A8C7-4F64-B08B-4702C55F...      Motorway     Dry
# Snapshot_2015.07.23_at_12.56.57.rec                      Highway     Dry
# Snapshot_2015.07.23_at_12.56.57.rec                         City     Dry
# Snapshot_2015.07.24_at_10.09.34.rec                     Motorway     Dry
# Continuous_2011.06.29_at_14.17.43.rec               Country_Road     Dry
# Continuous_2011.06.29_at_19.28.23.rec                   Motorway     Dry
# Snapshot_2015.07.23_at_13.04.26.rec                      Highway     Dry
# Continuous_2011.06.30_at_15.23.24.rec                   Motorway     Dry
# Continuous_2011.07.03_at_17.25.08.rec                   Motorway     Dry
# Continuous_2011.06.30_at_21.39.28.rec                   Motorway     Dry
# Continuous_2011.06.29_at_13.50.15.rec                       City     Dry
# Continuous_2011.07.03_at_16.49.42.rec                   Motorway     Dry
# Continuous_2011.06.30_at_12.58.39.rec                   Motorway     Dry
# Continuous_2012.09.13_at_12.19.46.rec                       City     Dry
# Continuous_2012.09.13_at_10.18.31.rec                   Motorway     Dry
# Continuous_2012.09.14_at_21.29.45.rec                   Motorway     Dry
# Continuous_2011.07.04_at_22.01.27.rec                   Motorway    Rain
# Continuous_2011.02.11_at_11.52.06.rec                       City     Dry
# Continuous_2011.02.11_at_11.52.06.rec                      Other     Dry
# Continuous_2011.02.11_at_11.52.06.rec                   Motorway     Dry
# Continuous_2011.02.11_at_11.52.06.rec                   Motorway     Dry
# Continuous_2011.02.11_at_11.52.06.rec                      Other     Dry
# Continuous_2011.02.11_at_11.52.06.rec                       City     Dry
# Continuous_2011.02.11_at_11.52.06.rec                      Other     Dry
# Continuous_2011.02.11_at_11.52.06.rec                   Motorway     Dry
# Snapshot_2015.11.09_at_11.32.35.rec                         City     Dry
# Continuous_2011.07.01_at_16.39.12.rec                   Motorway     Dry
# ...                                                          ...     ...
# Snapshot_2015.07.24_at_08.42.42.rec                      Highway     Dry
# 20141215_1540_{08627FB2-FDC3-414E-92B3-EBE39884...      Motorway     Dry
# Continuous_2011.02.11_at_14.25.37.rec                   Motorway     Dry
# Continuous_2011.02.09_at_20.47.57.rec                   Motorway     Dry
# Continuous_2011.02.10_at_15.30.37.rec               Country_Road     Dry
# Continuous_2011.06.27_at_16.22.12.rec                       City     Dry
# Continuous_2011.06.27_at_16.22.12.rec                   Motorway     Dry
# Continuous_2011.02.11_at_12.47.43.rec                   Motorway     Dry
# Continuous_2011.02.10_at_09.43.17.rec                   Motorway     Dry
# Continuous_2011.02.11_at_10.33.04.rec                   Motorway     Dry
# Continuous_2011.06.16_at_12.10.00.rec                       City     Dry
# Continuous_2011.06.16_at_12.10.00.rec                   Motorway     Dry
# Continuous_2011.06.16_at_14.02.06.rec                    Highway     Dry
# Continuous_2011.02.10_at_19.53.47.rec                       City     Dry
# Continuous_2011.02.10_at_19.53.47.rec               Country_Road     Dry
# Continuous_2011.07.01_at_17.53.11.rec                   Motorway     Dry
# Continuous_2011.07.04_at_22.13.36.rec               Country_Road    Rain
# Continuous_2011.02.09_at_09.43.21.rec                   Motorway     Dry
# Continuous_2014.11.25_at_17.45.07.rec                    Highway     Dry
# Continuous_2011.07.04_at_14.29.10.rec                   Motorway     Dry
# Continuous_2011.06.29_at_19.09.44.rec                   Motorway     Dry
# Continuous_2011.06.29_at_17.05.58.rec                       City     Dry
# Continuous_2011.06.29_at_19.40.59.rec               Country_Road     Dry
# Continuous_2011.07.04_at_19.14.47.rec               Country_Road     Dry
# Continuous_2011.07.04_at_19.30.58.rec               Country_Road     Dry
# Continuous_2011.07.04_at_19.28.05.rec               Country_Road     Dry
# Continuous_2011.07.04_at_19.32.57.rec               Country_Road     Dry
# Continuous_2012.04.18_at_20.53.17.rec               Country_Road     Dry
# Continuous_2012.04.18_at_20.53.17.rec               Country_Road     Dry
# Continuous_2012.04.18_at_20.53.17.rec                       City     Dry
#
#                                                    PROJECT FUNCTION
# RECFILENAME
# Continuous_2011.07.04_at_14.37.07.rec               MFC400     SR
# Continuous_2011.06.29_at_23.04.22.rec               MFC400     SR
# Continuous_2011.06.29_at_19.45.00.rec               MFC400     SR
# 20150731_0439_{7B17D7CD-A8C7-4F64-B08B-4702C55F...  MFC400     SR
# Snapshot_2015.07.23_at_12.56.57.rec                 MFC400     SR
# Snapshot_2015.07.23_at_12.56.57.rec                 MFC400     SR
# Snapshot_2015.07.24_at_10.09.34.rec                 MFC400     SR
# Continuous_2011.06.29_at_14.17.43.rec               MFC400     SR
# Continuous_2011.06.29_at_19.28.23.rec               MFC400     SR
# Snapshot_2015.07.23_at_13.04.26.rec                 MFC400     SR
# Continuous_2011.06.30_at_15.23.24.rec               MFC400     SR
# Continuous_2011.07.03_at_17.25.08.rec               MFC400     SR
# Continuous_2011.06.30_at_21.39.28.rec               MFC400     SR
# Continuous_2011.06.29_at_13.50.15.rec               MFC400     SR
# Continuous_2011.07.03_at_16.49.42.rec               MFC400     SR
# Continuous_2011.06.30_at_12.58.39.rec               MFC400     SR
# Continuous_2012.09.13_at_12.19.46.rec               MFC400     SR
# Continuous_2012.09.13_at_10.18.31.rec               MFC400     SR
# Continuous_2012.09.14_at_21.29.45.rec               MFC400     SR
# Continuous_2011.07.04_at_22.01.27.rec               MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec               MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec               MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec               MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec               MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec               MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec               MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec               MFC400     SR
# Continuous_2011.02.11_at_11.52.06.rec               MFC400     SR
# Snapshot_2015.11.09_at_11.32.35.rec                 MFC400     SR
# Continuous_2011.07.01_at_16.39.12.rec               MFC400     SR
# ...                                                    ...      ...
# Snapshot_2015.07.24_at_08.42.42.rec                 MFC400     SR
# 20141215_1540_{08627FB2-FDC3-414E-92B3-EBE39884...  MFC400     SR
# Continuous_2011.02.11_at_14.25.37.rec               MFC400     SR
# Continuous_2011.02.09_at_20.47.57.rec               MFC400     SR
# Continuous_2011.02.10_at_15.30.37.rec               MFC400     SR
# Continuous_2011.06.27_at_16.22.12.rec               MFC400     SR
# Continuous_2011.06.27_at_16.22.12.rec               MFC400     SR
# Continuous_2011.02.11_at_12.47.43.rec               MFC400     SR
# Continuous_2011.02.10_at_09.43.17.rec               MFC400     SR
# Continuous_2011.02.11_at_10.33.04.rec               MFC400     SR
# Continuous_2011.06.16_at_12.10.00.rec               MFC400     SR
# Continuous_2011.06.16_at_12.10.00.rec               MFC400     SR
# Continuous_2011.06.16_at_14.02.06.rec               MFC400     SR
# Continuous_2011.02.10_at_19.53.47.rec               MFC400     SR
# Continuous_2011.02.10_at_19.53.47.rec               MFC400     SR
# Continuous_2011.07.01_at_17.53.11.rec               MFC400     SR
# Continuous_2011.07.04_at_22.13.36.rec               MFC400     SR
# Continuous_2011.02.09_at_09.43.21.rec               MFC400     SR
# Continuous_2014.11.25_at_17.45.07.rec               MFC400     SR
# Continuous_2011.07.04_at_14.29.10.rec               MFC400     SR
# Continuous_2011.06.29_at_19.09.44.rec               MFC400     SR
# Continuous_2011.06.29_at_17.05.58.rec               MFC400     SR
# Continuous_2011.06.29_at_19.40.59.rec               MFC400     SR
# Continuous_2011.07.04_at_19.14.47.rec               MFC400     SR
# Continuous_2011.07.04_at_19.30.58.rec               MFC400     SR
# Continuous_2011.07.04_at_19.28.05.rec               MFC400     SR
# Continuous_2011.07.04_at_19.32.57.rec               MFC400     SR
# Continuous_2012.04.18_at_20.53.17.rec               MFC400     SR
# Continuous_2012.04.18_at_20.53.17.rec               MFC400     SR
# Continuous_2012.04.18_at_20.53.17.rec               MFC400     SR
#
# [99 rows x 7 columns]

# %%
# data_grp = sel_data.set_index(['COUNTRY','DEPARTMENT','LIGHT_CONDITIONS','PRJ_FUNC','ROAD_TYPE','WEATHER'])
# data_grp
# Get distinct rec names
distinct_rec_names = idx_rec_dtfr.index.unique()
# dir(distinct_rec_names)
rec_names_lst = distinct_rec_names.tolist()
rec_names_lst, len(rec_names_lst)
# Out:
# (['Continuous_2011.07.04_at_14.37.07.rec',
#   'Continuous_2011.06.29_at_23.04.22.rec',
#   'Continuous_2011.06.29_at_19.45.00.rec',
#   '20150731_0439_{7B17D7CD-A8C7-4F64-B08B-4702C55F3D32}.rrec',
#   'Snapshot_2015.07.23_at_12.56.57.rec',
#   'Snapshot_2015.07.24_at_10.09.34.rec',
#   'Continuous_2011.06.29_at_14.17.43.rec',
#   'Continuous_2011.06.29_at_19.28.23.rec',
#   'Snapshot_2015.07.23_at_13.04.26.rec',
#   'Continuous_2011.06.30_at_15.23.24.rec',
#   'Continuous_2011.07.03_at_17.25.08.rec',
#   'Continuous_2011.06.30_at_21.39.28.rec',
#   'Continuous_2011.06.29_at_13.50.15.rec',
#   'Continuous_2011.07.03_at_16.49.42.rec',
#   'Continuous_2011.06.30_at_12.58.39.rec',
#   'Continuous_2012.09.13_at_12.19.46.rec',
#   'Continuous_2012.09.13_at_10.18.31.rec',
#   'Continuous_2012.09.14_at_21.29.45.rec',
#   'Continuous_2011.07.04_at_22.01.27.rec',
#   'Continuous_2011.02.11_at_11.52.06.rec',
#   'Snapshot_2015.11.09_at_11.32.35.rec',
#   'Continuous_2011.07.01_at_16.39.12.rec',
#   'Snapshot_2015.11.09_at_13.40.38.rec',
#   'Continuous_2012.09.11_at_17.47.17.rec',
#   'Continuous_2012.09.11_at_19.29.46.rec',
#   'Continuous_2012.09.12_at_22.25.49.rec',
#   'Continuous_2011.02.11_at_18.13.23.rec',
#   'Continuous_2011.02.11_at_09.38.03.rec',
#   'Continuous_2011.06.27_at_15.57.24.rec',
#   'Continuous_2011.06.27_at_14.49.01.rec',
#   'Continuous_2011.06.27_at_16.03.03.rec',
#   'Continuous_2011.06.27_at_17.51.03.rec',
#   'Continuous_2011.07.01_at_17.19.25.rec',
#   'Continuous_2011.06.27_at_18.10.48.rec',
#   'Continuous_2011.06.27_at_18.26.35.rec',
#   'Continuous_2011.06.27_at_17.35.32.rec',
#   'Continuous_2011.06.27_at_17.24.42.rec',
#   'Continuous_2011.02.11_at_18.21.13.rec',
#   'Continuous_2011.06.29_at_15.14.40.rec',
#   'Continuous_2011.07.01_at_18.01.15.rec',
#   'Continuous_2011.07.04_at_12.19.56.rec',
#   'Continuous_2012.09.13_at_14.58.53.rec',
#   'Continuous_2011.06.29_at_13.04.19.rec',
#   'Continuous_2011.06.10_at_13.44.14.rec',
#   'Continuous_2011.06.10_at_22.40.17.rec',
#   'Continuous_2011.06.27_at_14.52.04.rec',
#   'Snapshot_2015.07.24_at_08.42.42.rec',
#   '20141215_1540_{08627FB2-FDC3-414E-92B3-EBE39884DA8F}.rrec',
#   'Continuous_2011.02.11_at_14.25.37.rec',
#   'Continuous_2011.02.09_at_20.47.57.rec',
#   'Continuous_2011.02.10_at_15.30.37.rec',
#   'Continuous_2011.06.27_at_16.22.12.rec',
#   'Continuous_2011.02.11_at_12.47.43.rec',
#   'Continuous_2011.02.10_at_09.43.17.rec',
#   'Continuous_2011.02.11_at_10.33.04.rec',
#   'Continuous_2011.06.16_at_12.10.00.rec',
#   'Continuous_2011.06.16_at_14.02.06.rec',
#   'Continuous_2011.02.10_at_19.53.47.rec',
#   'Continuous_2011.07.01_at_17.53.11.rec',
#   'Continuous_2011.07.04_at_22.13.36.rec',
#   'Continuous_2011.02.09_at_09.43.21.rec',
#   'Continuous_2014.11.25_at_17.45.07.rec',
#   'Continuous_2011.07.04_at_14.29.10.rec',
#   'Continuous_2011.06.29_at_19.09.44.rec',
#   'Continuous_2011.06.29_at_17.05.58.rec',
#   'Continuous_2011.06.29_at_19.40.59.rec',
#   'Continuous_2011.07.04_at_19.14.47.rec',
#   'Continuous_2011.07.04_at_19.30.58.rec',
#   'Continuous_2011.07.04_at_19.28.05.rec',
#   'Continuous_2011.07.04_at_19.32.57.rec',
#   'Continuous_2012.04.18_at_20.53.17.rec'],
#  71)

# %%
# sel_data = idx_rec_dtfr.loc['Snapshot_2015.07.23_at_12.56.57.rec']
# sel_data

# %%
# ech_rec_dtfr = sel_data.reset_index()
# country = ech_rec_dtfr['COUNTRY'].unique().tolist()
# dpt_type = ech_rec_dtfr['DEPARTMENT'].unique().tolist()
# lc_type = ech_rec_dtfr['LIGHT_CONDITIONS'].unique().tolist()
# prj_type = ech_rec_dtfr['PROJECT'].unique().tolist()
# func_type = ech_rec_dtfr['FUNCTION'].unique().tolist()
# rd_type = ech_rec_dtfr['ROAD_TYPE'].unique().tolist()
# wthr_type = ech_rec_dtfr['WEATHER'].unique().tolist()
# rd_type

# %%
# clmn_names_lst = sel_data.columns.tolist()
# clmn_names_lst

# %%
# Iterate through each recording

lst_data = []
for ech_rec in rec_names_lst:
    rec_dict = {}
    sel_data = idx_rec_dtfr.loc[ech_rec]
#     print ">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>"
#     print sel_data
    ech_rec_dtfr = sel_data
#     print ech_rec_dtfr
    rec_dict['RECFILENAME'] = ech_rec
    
    for ech_clmn_name in clmn_names_lst:
#         print ech_rec_dtfr[ech_clmn_name]
        if type(ech_rec_dtfr) is pd.Series:
            clmn_data = ech_rec_dtfr[ech_clmn_name]
#             print ">>>", clmn_data
            rec_dict[ech_clmn_name] = [clmn_data]
        else:
            clmn_data = ech_rec_dtfr[ech_clmn_name].unique().tolist()
            rec_dict[ech_clmn_name] = clmn_data
#     print "rec_dict :: ", rec_dict
    lst_data.append(rec_dict)

# %%
lst_data
# Out:
# [{'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.04_at_14.37.07.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.29_at_23.04.22.rec',
#   'ROAD_TYPE': ['Highway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.29_at_19.45.00.rec',
#   'ROAD_TYPE': ['Country_Road'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Hungary'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': '20150731_0439_{7B17D7CD-A8C7-4F64-B08B-4702C55F3D32}.rrec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Germany'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Snapshot_2015.07.23_at_12.56.57.rec',
#   'ROAD_TYPE': ['Highway', 'City'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Germany'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Snapshot_2015.07.24_at_10.09.34.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.29_at_14.17.43.rec',
#   'ROAD_TYPE': ['Country_Road'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.29_at_19.28.23.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Germany'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Snapshot_2015.07.23_at_13.04.26.rec',
#   'ROAD_TYPE': ['Highway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.30_at_15.23.24.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.03_at_17.25.08.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.30_at_21.39.28.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.29_at_13.50.15.rec',
#   'ROAD_TYPE': ['City'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.03_at_16.49.42.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.30_at_12.58.39.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Great_Britain'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2012.09.13_at_12.19.46.rec',
#   'ROAD_TYPE': ['City'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Great_Britain'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2012.09.13_at_10.18.31.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Germany'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2012.09.14_at_21.29.45.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.04_at_22.01.27.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Rain']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.02.11_at_11.52.06.rec',
#   'ROAD_TYPE': ['City', 'Other', 'Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Austria'],
#   'DEPARTMENT': ['EVA'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Snapshot_2015.11.09_at_11.32.35.rec',
#   'ROAD_TYPE': ['City'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.01_at_16.39.12.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Austria'],
#   'DEPARTMENT': ['EVA'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Snapshot_2015.11.09_at_13.40.38.rec',
#   'ROAD_TYPE': ['City'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Luxemburg'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2012.09.11_at_17.47.17.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Rain']},
#  {'COUNTRY': ['Belgium'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2012.09.11_at_19.29.46.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Great_Britain'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2012.09.12_at_22.25.49.rec',
#   'ROAD_TYPE': ['Country_Road', 'Highway'],
#   'WEATHER': ['Dry', 'Rain']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.02.11_at_18.13.23.rec',
#   'ROAD_TYPE': ['Highway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.02.11_at_09.38.03.rec',
#   'ROAD_TYPE': ['City'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.27_at_15.57.24.rec',
#   'ROAD_TYPE': ['Motorway', 'Country_Road', 'City'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.27_at_14.49.01.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.27_at_16.03.03.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.27_at_17.51.03.rec',
#   'ROAD_TYPE': ['Highway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.01_at_17.19.25.rec',
#   'ROAD_TYPE': ['Country_Road', 'Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.27_at_18.10.48.rec',
#   'ROAD_TYPE': ['City'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.27_at_18.26.35.rec',
#   'ROAD_TYPE': ['Country_Road'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.27_at_17.35.32.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.27_at_17.24.42.rec',
#   'ROAD_TYPE': ['City', 'Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.02.11_at_18.21.13.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.29_at_15.14.40.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Dusk'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.01_at_18.01.15.rec',
#   'ROAD_TYPE': ['Highway'],
#   'WEATHER': ['Rain']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.04_at_12.19.56.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Great_Britain'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2012.09.13_at_14.58.53.rec',
#   'ROAD_TYPE': ['Country_Road', 'City', 'Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.29_at_13.04.19.rec',
#   'ROAD_TYPE': ['Country_Road'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['EVA'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.10_at_13.44.14.rec',
#   'ROAD_TYPE': ['City'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['EVA'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.10_at_22.40.17.rec',
#   'ROAD_TYPE': ['Country_Road'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.27_at_14.52.04.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Germany'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Snapshot_2015.07.24_at_08.42.42.rec',
#   'ROAD_TYPE': ['City', 'Highway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['Italy'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': '20141215_1540_{08627FB2-FDC3-414E-92B3-EBE39884DA8F}.rrec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.02.11_at_14.25.37.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.02.09_at_20.47.57.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.02.10_at_15.30.37.rec',
#   'ROAD_TYPE': ['Country_Road'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.27_at_16.22.12.rec',
#   'ROAD_TYPE': ['City', 'Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.02.11_at_12.47.43.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.02.10_at_09.43.17.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.02.11_at_10.33.04.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.16_at_12.10.00.rec',
#   'ROAD_TYPE': ['City', 'Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.16_at_14.02.06.rec',
#   'ROAD_TYPE': ['Highway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.02.10_at_19.53.47.rec',
#   'ROAD_TYPE': ['City', 'Country_Road'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.01_at_17.53.11.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.04_at_22.13.36.rec',
#   'ROAD_TYPE': ['Country_Road'],
#   'WEATHER': ['Rain']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.02.09_at_09.43.21.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['TAIWAN'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2014.11.25_at_17.45.07.rec',
#   'ROAD_TYPE': ['Highway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.04_at_14.29.10.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.29_at_19.09.44.rec',
#   'ROAD_TYPE': ['Motorway'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.29_at_17.05.58.rec',
#   'ROAD_TYPE': ['City'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.06.29_at_19.40.59.rec',
#   'ROAD_TYPE': ['Country_Road'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Dusk'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.04_at_19.14.47.rec',
#   'ROAD_TYPE': ['Country_Road'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Dusk'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.04_at_19.30.58.rec',
#   'ROAD_TYPE': ['Country_Road'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.04_at_19.28.05.rec',
#   'ROAD_TYPE': ['Country_Road'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['USA'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Day'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2011.07.04_at_19.32.57.rec',
#   'ROAD_TYPE': ['Country_Road'],
#   'WEATHER': ['Dry']},
#  {'COUNTRY': ['France'],
#   'DEPARTMENT': ['DEV'],
#   'FUNCTION': ['SR  '],
#   'LIGHT_CONDITIONS': ['Night'],
#   'PROJECT': ['MFC400'],
#   'RECFILENAME': 'Continuous_2012.04.18_at_20.53.17.rec',
#   'ROAD_TYPE': ['Country_Road', 'City'],
#   'WEATHER': ['Dry']}]

# %%
# Dump the data into a JSON
import json
with open("ldss.json", 'w+') as outfile:
    json.dump(lst_data, outfile, indent=4)
